# %%
list=[1,2,3,[],4,5,[],6]
print("Original list is:", list)
list=[i for i in list if i!=[] ]
print("Removal of empty list from list:" , str(list))
# Out:
# Original list is: [1, 2, 3, [], 4, 5, [], 6]
# Removal of empty list from list: [1, 2, 3, 4, 5, 6]

# %%
str1=input("Enter the sentence:")
list=str1.split(" ")
k=[]
print(" ")
for i in list:
    if i not in k:
        k.append(i)
print("Removal of duplicate words from the sentence: "," ".join(k))
# Out:
# Enter the sentence:windows is operating system and linux also operating system
#
# Removal of duplicate words from the sentence:  windows is operating system and linux also

# %%
str1=input("Enter the sentence:")
char=input("Enter the charecter to find:")
num=0
for i in str1:
    if char==i:
        num = num + 1
print("Occurance of charecter", char,"is:",num)
# Out:
# Enter the sentence:python is programming language
# Enter the charecter to find:g
# Occurance of charecter g is: 4
